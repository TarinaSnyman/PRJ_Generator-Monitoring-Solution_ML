# %%
# AnomalyDetection_12305.ipynb — Full optimized anomaly detection for AiR 12305
import os
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest
from sklearn.svm import OneClassSVM
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# -------------------------
# 0. Config / Parameters
# -------------------------
RAW_FEATURES = "../../data/processed/air_12305_features_full.parquet"  # input
OUT_PATH = "../../data/processed/air_12305_anomalies.parquet"        # output
SAMPLE_SIZE = 50000            # sample to train IF / OCSVM (50k is a good balance)
IF_N_ESTIMATORS = 150
IF_CONTAMINATION = 0.02        # expected fraction of anomalies for IF
OCSVM_NU = 0.03                # expected fraction of anomalies for OCSVM
PREDICT_CHUNK = 20000         # chunk size for making OCSVM predictions to save memory

np.random.seed(42)

# -------------------------
# 1. Load features
# -------------------------
print("Loading features:", RAW_FEATURES)
df = pd.read_parquet(RAW_FEATURES)
print("Initial shape:", df.shape)

# Ensure time exists
if 'time' in df.columns:
    df['time'] = pd.to_datetime(df['time'], errors='coerce')
else:
    df['time'] = pd.NaT

# -------------------------
# 2. Clean up obvious sensor overflows / placeholders
# -------------------------
print("Cleaning placeholder/overflow values...")
PLACEHOLDER_THRESHOLD = 1e8   # values greater than this are likely invalid placeholders
sensor_cols = [
    'ptot_watt', 'ia_ampere', 'ib_ampere', 'ic_ampere',
    'va_volt', 'vb_volt', 'vc_volt',
    'cooltemp_degree-celsius', 'oilpress_pascal', 'vbat_volt'
]
present_sensors = [c for c in sensor_cols if c in df.columns]
for c in present_sensors:
    # replace extremely large values with NaN
    df.loc[df[c].abs() > PLACEHOLDER_THRESHOLD, c] = np.nan

# Basic imputation: forward fill then median fallback (keeps time-series structure)
df.sort_values('time', inplace=True)
df.fillna(method='ffill', inplace=True)
df.fillna(df.median(numeric_only=True), inplace=True)
df.reset_index(drop=True, inplace=True)

# -------------------------
# 3. Build features for anomaly detection
# -------------------------
# We'll use a focused subset of columns that are physically meaningful and available
base_features = []
for c in ['ptot_watt', 'ia_ampere', 'ib_ampere', 'ic_ampere',
          'cooltemp_degree-celsius', 'oilpress_pascal', 'vbat_volt']:
    if c in df.columns:
        base_features.append(c)

if len(base_features) == 0:
    raise ValueError("No base features found for anomaly detection. Check columns.")

print("Using features:", base_features)

# Optionally add engineered features if present (current imbalance, pf_anomaly, etc.)
engineered = [c for c in ['current_imbalance', 'pf_anomaly', 'ptot_watt_rollstd', 'temp_roll_mean'] if c in df.columns]
feature_cols = base_features + engineered
print("Final feature set:", feature_cols)

X = df[feature_cols].astype(float).fillna(0).values

# -------------------------
# 4. Scale features
# -------------------------
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  # scale whole dataset (will use same scaler for sampled training)

# -------------------------
# 5. Prepare training sample for ML detectors (downsample)
# -------------------------
n = len(X_scaled)
sample_size = min(SAMPLE_SIZE, n)
sample_idx = np.random.choice(n, size=sample_size, replace=False)
X_sample = X_scaled[sample_idx]

print(f"Using sample_size={sample_size} to train IsolationForest and OCSVM.")

# -------------------------
# 6. Train Isolation Forest (fast & robust)
# -------------------------
print("Training IsolationForest...")
iso = IsolationForest(
    n_estimators=IF_N_ESTIMATORS,
    contamination=IF_CONTAMINATION,
    max_samples=min(256, sample_size),
    random_state=42,
    n_jobs=-1
)
iso.fit(X_sample)

# Predict full dataset (IF)
print("Predicting IsolationForest on full dataset...")
if_preds = iso.predict(X_scaled)            # 1 = normal, -1 = anomaly
df['anomaly_iforest'] = (if_preds == -1).astype(int)
print("IF anomalies:", int(df['anomaly_iforest'].sum()))

# -------------------------
# 7. Train One-Class SVM on sample + predict in chunks
# -------------------------
print("Training One-Class SVM on sample (this may take a little time)...")
ocsvm = OneClassSVM(kernel='rbf', gamma='scale', nu=OCSVM_NU)
ocsvm.fit(X_sample)

# Predict in chunks to avoid memory/time spikes
svm_preds = np.zeros(n, dtype=int)
print("Predicting OCSVM on full dataset in chunks...")
for start in range(0, n, PREDICT_CHUNK):
    end = min(start + PREDICT_CHUNK, n)
    chunk = X_scaled[start:end]
    preds = ocsvm.predict(chunk)  # 1 = inlier (normal), -1 = outlier
    svm_preds[start:end] = (preds == -1).astype(int)
df['anomaly_ocsvm'] = svm_preds
print("OCSVM anomalies:", int(df['anomaly_ocsvm'].sum()))

# -------------------------
# 8. Improved heuristic-based anomaly detection
# -------------------------
print("Computing improved heuristic-based anomaly flags...")

df['anomaly_heur_temp'] = 0
df['anomaly_heur_current'] = 0
df['anomaly_heur_voltage'] = 0
df['anomaly_heur_power'] = 0
df['anomaly_heur_oilbat'] = 0

# Detect "off" periods (zero-like readings)
off_mask = (df['ptot_watt'] < 1e5) & (df['ia_ampere'] < 1e4)
on_df = df[~off_mask]

def q(x, low=0.005, high=0.995):
    return x.quantile([low, high]).values if len(x) > 0 else (0, 0)

# Temperature anomalies
if 'cooltemp_degree-celsius' in df.columns:
    t_low, t_high = q(on_df['cooltemp_degree-celsius'], 0.002, 0.998)
    df.loc[(df['cooltemp_degree-celsius'] < t_low) | (df['cooltemp_degree-celsius'] > t_high), 'anomaly_heur_temp'] = 1

# Current imbalance
if 'current_imbalance' in df.columns:
    cur_thresh = on_df['current_imbalance'].quantile(0.999)
    df.loc[df['current_imbalance'] > cur_thresh, 'anomaly_heur_current'] = 1

# Voltage anomalies
for col in ['va_volt', 'vb_volt', 'vc_volt', 'vbat_volt']:
    if col in df.columns:
        low, high = q(on_df[col], 0.001, 0.999)
        df.loc[(df[col] < low) | (df[col] > high), 'anomaly_heur_voltage'] = 1

# Power anomalies: generator ON but power = 0
df.loc[(~off_mask) & (df['ptot_watt'] < 1000), 'anomaly_heur_power'] = 1

# Oil/battery
if 'oilpress_pascal' in df.columns and 'vbat_volt' in df.columns:
    oil_low = on_df['oilpress_pascal'].quantile(0.001)
    batt_low = on_df['vbat_volt'].quantile(0.001)
    df.loc[(df['oilpress_pascal'] < oil_low) | (df['vbat_volt'] < batt_low), 'anomaly_heur_oilbat'] = 1

# Combine
heur_cols = ['anomaly_heur_temp','anomaly_heur_current','anomaly_heur_voltage',
             'anomaly_heur_power','anomaly_heur_oilbat']
df['anomaly_heuristic'] = df[heur_cols].max(axis=1).astype(int)
print("Improved heuristic anomalies:", int(df['anomaly_heuristic'].sum()))

# -------------------------
# 9. Combine detectors -> votes & final label
# -------------------------
print("Combining detectors into anomaly_votes and final label...")
# Make sure columns exist
for col in ['anomaly_iforest','anomaly_ocsvm','anomaly_heuristic']:
    if col not in df.columns:
        df[col] = 0

df['anomaly_votes'] = df[['anomaly_iforest','anomaly_ocsvm','anomaly_heuristic']].sum(axis=1)
# final label: anomaly if at least two methods agree (tune this threshold if desired)
df['is_anomaly'] = (df['anomaly_votes'] >= 2).astype(int)

print("Anomaly votes distribution:\n", df['anomaly_votes'].value_counts().sort_index())
print("Final anomalies (is_anomaly):", int(df['is_anomaly'].sum()))

# -------------------------
# 10. Diagnostics & quick plots
# -------------------------
print("\nSample diagnostics:")
print(df[['anomaly_iforest','anomaly_ocsvm','anomaly_heuristic','anomaly_votes','is_anomaly']].sum())

# Print a few anomaly windows where all 3 voted (if any)
agree3 = df[df['anomaly_votes'] == 3]
if len(agree3) > 0 and 'time' in df.columns:
    print("Examples where all 3 detectors agree (up to 5):")
    for t in agree3['time'].head(5):
        window = df[(df['time'] >= (t - pd.Timedelta("30min"))) & (df['time'] <= (t + pd.Timedelta("30min")))]
        print("\n--- Window around", t, " ---")
        display(window.head())

# Quick time series plot showing anomalies over power (if columns exist)
try:
    if 'ptot_watt' in df.columns and 'time' in df.columns:
        sample = df.copy().set_index('time').resample('15min').mean(numeric_only=True)
        a = df[df['is_anomaly']==1].set_index('time').resample('15min').size()
        plt.figure(figsize=(12,4))
        plt.plot(sample.index, sample['ptot_watt'], label='Power (15min avg)')
        if len(a) > 0:
            plt.scatter(a.index, [sample['ptot_watt'].max()*0.9]*len(a), color='red', s=10, label='Anomaly count')
        plt.legend()
        plt.title('AiR 12305 – ptot_watt with anomalies')
        plt.show()
except Exception as e:
    print("Plotting skipped:", e)

# -------------------------
# 11. Save results
# -------------------------
print("Saving anomaly-labelled dataset to:", OUT_PATH)
df.to_parquet(OUT_PATH, index=False)
print("Saved. Done.")
# Out:
# Loading features: ../../data/processed/air_12305_features_full.parquet
# Initial shape: (561924, 42)
# Cleaning placeholder/overflow values...
# C:\Users\tiaan\AppData\Local\Temp\ipykernel_37372\528540928.py:53: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)
# Using features: ['ptot_watt', 'ia_ampere', 'ib_ampere', 'ic_ampere', 'cooltemp_degree-celsius', 'oilpress_pascal', 'vbat_volt']
# Final feature set: ['ptot_watt', 'ia_ampere', 'ib_ampere', 'ic_ampere', 'cooltemp_degree-celsius', 'oilpress_pascal', 'vbat_volt', 'current_imbalance', 'pf_anomaly', 'ptot_watt_rollstd', 'temp_roll_mean']
# Using sample_size=50000 to train IsolationForest and OCSVM.
# Training IsolationForest...
# Predicting IsolationForest on full dataset...
# IF anomalies: 11064
# Training One-Class SVM on sample (this may take a little time)...
# ...
